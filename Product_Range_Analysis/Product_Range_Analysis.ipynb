# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Decomposition-of-the-e-commerse-task:-Product-Range-Analisys" data-toc-modified-id="Decomposition-of-the-e-commerse-task:-Product-Range-Analisys-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Decomposition of the e-commerse task: Product Range Analisys</a></span></li></ul></li><li><span><a href="#Data-preprocessing-and-EDA" data-toc-modified-id="Data-preprocessing-and-EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data preprocessing and EDA</a></span><ul class="toc-item"><li><span><a href="#General-info-about-the-data" data-toc-modified-id="General-info-about-the-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>General info about the data</a></span><ul class="toc-item"><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Working-with-quality-of-the-data" data-toc-modified-id="Working-with-quality-of-the-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Working with quality of the data</a></span><ul class="toc-item"><li><span><a href="#Prepare-the-data---rename-columns,-change-data-types-if-needed" data-toc-modified-id="Prepare-the-data---rename-columns,-change-data-types-if-needed-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Prepare the data - rename columns, change data types if needed</a></span></li><li><span><a href="#Work-with-missing-values,-duplicates,-etc." data-toc-modified-id="Work-with-missing-values,-duplicates,-etc.-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Work with missing values, duplicates, etc.</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Looking-for-connections-and-relations-in-the-data,-plotting-graphs" data-toc-modified-id="Looking-for-connections-and-relations-in-the-data,-plotting-graphs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Looking for connections and relations in the data, plotting graphs</a></span><ul class="toc-item"><li><span><a href="#Sales-per-month" data-toc-modified-id="Sales-per-month-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Sales per month</a></span><ul class="toc-item"><li><span><a href="#Revenue-graphs" data-toc-modified-id="Revenue-graphs-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span>Revenue graphs</a></span></li><li><span><a href="#Revenue-stats-with-outliers" data-toc-modified-id="Revenue-stats-with-outliers-1.3.1.2"><span class="toc-item-num">1.3.1.2&nbsp;&nbsp;</span>Revenue stats with outliers</a></span></li></ul></li><li><span><a href="#Revenue-stats-without-outliers" data-toc-modified-id="Revenue-stats-without-outliers-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Revenue stats without outliers</a></span></li><li><span><a href="#Revenue-graphs-without-outliers" data-toc-modified-id="Revenue-graphs-without-outliers-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Revenue graphs without outliers</a></span></li><li><span><a href="#Orders" data-toc-modified-id="Orders-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Orders</a></span><ul class="toc-item"><li><span><a href="#Item's-quantity-graphs" data-toc-modified-id="Item's-quantity-graphs-1.3.4.1"><span class="toc-item-num">1.3.4.1&nbsp;&nbsp;</span>Item's quantity graphs</a></span></li></ul></li><li><span><a href="#Item's-quantity-graphs-without-outliers" data-toc-modified-id="Item's-quantity-graphs-without-outliers-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Item's quantity graphs without outliers</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Studing-products" data-toc-modified-id="Studing-products-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Studing products</a></span><ul class="toc-item"><li><span><a href="#Categorize-products" data-toc-modified-id="Categorize-products-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Categorize products</a></span></li><li><span><a href="#Category-graphs" data-toc-modified-id="Category-graphs-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Category graphs</a></span></li><li><span><a href="#Prices" data-toc-modified-id="Prices-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Prices</a></span></li><li><span><a href="#Prices-graphs" data-toc-modified-id="Prices-graphs-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Prices graphs</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Study-sales-in-terms-of-categories" data-toc-modified-id="Study-sales-in-terms-of-categories-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Study sales in terms of categories</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Most-profitable-categories" data-toc-modified-id="Most-profitable-categories-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Most profitable categories</a></span></li><li><span><a href="#Graph:-revenue-form-the-most-profitable-categories-per-month" data-toc-modified-id="Graph:-revenue-form-the-most-profitable-categories-per-month-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Graph: revenue form the most profitable categories per month</a></span></li></ul></li></ul></li><li><span><a href="#Study-market-baskets" data-toc-modified-id="Study-market-baskets-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Study market baskets</a></span><ul class="toc-item"><li><span><a href="#Prepare-the-data-for-apriory-algorythm" data-toc-modified-id="Prepare-the-data-for-apriory-algorythm-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prepare the data for apriory algorythm</a></span></li><li><span><a href="#Implementing-Apriori" data-toc-modified-id="Implementing-Apriori-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Implementing Apriori</a></span></li></ul></li><li><span><a href="#Statistical-hypotheses" data-toc-modified-id="Statistical-hypotheses-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Statistical hypotheses</a></span><ul class="toc-item"><li><span><a href="#The-average-revenue-from-the-clients-who-purchased-once-doesn't-differs-from-the-average-revenue-from-the-clients-who-made-multiple-orders." data-toc-modified-id="The-average-revenue-from-the-clients-who-purchased-once-doesn't-differs-from-the-average-revenue-from-the-clients-who-made-multiple-orders.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>The average revenue from the clients who purchased once doesn't differs from the average revenue from the clients who made multiple orders.</a></span></li><li><span><a href="#Is-the-average-revenue-from-the-orders-with-at-least-one-item-from-kitchenware-differs-than-the-average-revenue-from-the-orders-with-at-least-one-iten-from-decor" data-toc-modified-id="Is-the-average-revenue-from-the-orders-with-at-least-one-item-from-kitchenware-differs-than-the-average-revenue-from-the-orders-with-at-least-one-iten-from-decor-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Is the average revenue from the orders with at least one item from kitchenware differs than the average revenue from the orders with at least one iten from decor</a></span></li></ul></li><li><span><a href="#General-conclusions" data-toc-modified-id="General-conclusions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>General conclusions</a></span><ul class="toc-item"><li><span><a href="#Sources" data-toc-modified-id="Sources-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Sources</a></span></li><li><span><a href="#Presentation" data-toc-modified-id="Presentation-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Presentation</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### Decomposition of the e-commerse task: Product Range Analisys
#
# The purpose of this project is to find the most advantageous items and to get rid of the unprofitable ones. And in the long run to help business grow loyal clients and increase profit.
#
# Important note: since we don't have any information about costs. That why we are able to evaluate only gross calculations. So, even popular products with high income could be not that profitable.

# %% [markdown]
# **Data overview**
#
# Initial data overview - just to see what we are dealing with - to formulate decomposition better.

# %% [markdown]
# We've been given the data with 541909 entries, 6 columns. There is 25900 invoices (=orders), 4372 unique stock codes (=goods), 4070 customers id's (=clients), data range – 12/21/2018-01/02/2019.
#
# Numbers could change during the research, because of mistakes or duplicates, so this is our first approach before the actual investigation.

# %% [markdown]
# ## Data preprocessing and EDA

# %% [markdown]
# ### General info about the data

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from scipy import stats as st
from scipy.stats import levene
import datetime as dt
import nltk
from nltk.stem import WordNetLemmatizer 
from collections import Counter
#from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from scipy.stats import norm
from scipy.stats import shapiro
from scipy.stats import mannwhitneyu
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install mlxtend

# %%
import spacy

# %%
try:
    goods = pd.read_csv('./datasets/ecommerce_dataset_us.csv',sep='\t')
except:
    goods = pd.read_csv('https://code.s3.yandex.net/datasets/ecommerce_dataset_us.csv', sep='\t')

# %%
goods.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID
# 0  11/29/2018 08:26       2.55     17850.0
# 1  11/29/2018 08:26       3.39     17850.0
# 2  11/29/2018 08:26       2.75     17850.0
# 3  11/29/2018 08:26       3.39     17850.0
# 4  11/29/2018 08:26       3.39     17850.0

# %%
goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 28.9+ MB

# %%
goods.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
goods['InvoiceNo'].nunique()
# Out:
# 25900

# %%
goods['CustomerID'].nunique()
# Out:
# 4372

# %%
goods['InvoiceDate'].min()
# Out:
# '01/02/2019 10:00'

# %%
goods['InvoiceDate'].max()
# Out:
# '12/21/2018 17:41'

# %%
goods['StockCode'].nunique()
# Out:
# 4070

# %% [markdown]
# #### Conclusion
# We have a table with 541909 rows and 7 columns.
#
# - InvoiceNo    541909 non-null  object
# - StockCode    541909 non-null  object
# - Description  540455 non-null  object
# - Quantity     541909 non-null  int64
# - InvoiceDate  541909 non-null  object
# - UnitPrice    541909 non-null  float64
# - CustomerID   406829 non-null  float64
#
# At first approach we have 25 900 invoices, 4372 itmes with 4070 unique stock codes and missing values in the customer id column and description column.

# %% [markdown]
# ### Working with quality of the data

# %% [markdown]
# #### Prepare the data - rename columns, change data types if needed

# %%
#get rid of Uppercase
goods.columns=goods.columns.str.lower()
#rename column
goods = goods.rename(columns={'invoiceno': 'order', 'stockcode': 'stock_code', 'invoicedate': 'date', 'unitprice': 'unit_price', 'customerid': 'customer_id'})
#check the result
goods.head()
# Out:
#     order stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                date  unit_price  customer_id
# 0  11/29/2018 08:26        2.55      17850.0
# 1  11/29/2018 08:26        3.39      17850.0
# 2  11/29/2018 08:26        2.75      17850.0
# 3  11/29/2018 08:26        3.39      17850.0
# 4  11/29/2018 08:26        3.39      17850.0

# %%
goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order        541909 non-null  object
#  1   stock_code   541909 non-null  object
#  2   description  540455 non-null  object
#  3   quantity     541909 non-null  int64
#  4   date         541909 non-null  object
#  5   unit_price   541909 non-null  float64
#  6   customer_id  406829 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 28.9+ MB

# %%
#change data types
goods['date']= pd.to_datetime(goods['date'])
#goods['customer_id'] = goods['customer_id'].astype(int)
goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order        541909 non-null  object
#  1   stock_code   541909 non-null  object
#  2   description  540455 non-null  object
#  3   quantity     541909 non-null  int64
#  4   date         541909 non-null  datetime64[ns]
#  5   unit_price   541909 non-null  float64
#  6   customer_id  406829 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 28.9+ MB

# %%
print(
goods['date'].min(),
goods['date'].max())
# Out:
# 2018-11-29 08:26:00 2019-12-07 12:50:00

# %% [markdown]
# #### Work with missing values, duplicates, etc.

# %% [markdown]
# Investigate description and customer_id columns wich contain some missing values

# %%
goods.isna().sum()
# Out:
# order               0
# stock_code          0
# description      1454
# quantity            0
# date                0
# unit_price          0
# customer_id    135080
# dtype: int64

# %%
percentage_missing_values=goods.isna().sum()/len(goods)
percentage_missing_values
# Out:
# order          0.000000
# stock_code     0.000000
# description    0.002683
# quantity       0.000000
# date           0.000000
# unit_price     0.000000
# customer_id    0.249267
# dtype: float64

# %% [markdown]
# Percetage of the missing values in the description column is less than 1%, so it wouldn't corrupt our research if we drop rows with missing values.

# %%
#investigate missing values in the customer_id column
null_id=goods[goods['customer_id'].isna()]
null_id
# Out:
#          order stock_code                      description  quantity  \
# 622     536414      22139                              NaN        56
# 1443    536544      21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544      21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544      21786               POLKADOT RAIN HAT          4
# 1446    536544      21787            RAIN PONCHO RETROSPOT         2
# ...        ...        ...                              ...       ...
# 541536  581498     85099B          JUMBO BAG RED RETROSPOT         5
# 541537  581498     85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538  581498      85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539  581498      85174                S/4 CACTI CANDLES         1
# 541540  581498        DOT                   DOTCOM POSTAGE         1
#
#                       date  unit_price  customer_id
# 622    2018-11-29 11:52:00        0.00          NaN
# ...

# %% [markdown]
# Lot's of missing customer id's can't be ignored. Let's try ti find out is there same invoices but with customer id.

# %%
null_id_orders=null_id['order'].unique()
null_id_orders
# Out:
# array(['536414', '536544', '536545', ..., '581492', '581497', '581498'],
#       dtype=object)

# %%
goods[goods['order']== '581498']['customer_id']
# Out:
# 541323   NaN
# 541324   NaN
# 541325   NaN
# 541326   NaN
# 541327   NaN
#           ..
# 541536   NaN
# 541537   NaN
# 541538   NaN
# 541539   NaN
# 541540   NaN
# Name: customer_id, Length: 218, dtype: float64

# %%
#check particular invoice
goods[goods['order']== '581498']['customer_id'].unique()
# Out:
# array([nan])

# %%
#check if there is any invoice with filled cusomer id 
goods.query('order in @null_id_orders')['customer_id'].unique()
# Out:
# array([nan])

# %%
no_customer_orders=goods.query('order in @null_id_orders')
no_customer_orders
# Out:
#          order stock_code                      description  quantity  \
# 622     536414      22139                              NaN        56
# 1443    536544      21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544      21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544      21786               POLKADOT RAIN HAT          4
# 1446    536544      21787            RAIN PONCHO RETROSPOT         2
# ...        ...        ...                              ...       ...
# 541536  581498     85099B          JUMBO BAG RED RETROSPOT         5
# 541537  581498     85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538  581498      85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539  581498      85174                S/4 CACTI CANDLES         1
# 541540  581498        DOT                   DOTCOM POSTAGE         1
#
#                       date  unit_price  customer_id
# 622    2018-11-29 11:52:00        0.00          NaN
# ...

# %% [markdown]
# Quite strange, but we couldn't identify any of the ghost customers by invoice numbers.

# %%
#looking for a strange orders - without description, customer and price
corrupted_orders=goods.query('order in @null_id_orders & unit_price == 0')
corrupted_orders
# Out:
#          order stock_code                   description  quantity  \
# 622     536414      22139                           NaN        56
# 1970    536545      21134                           NaN         1
# 1971    536546      22145                           NaN         1
# 1972    536547      37509                           NaN         1
# 1987    536549     85226A                           NaN         1
# ...        ...        ...                           ...       ...
# 536981  581234      72817                           NaN        27
# 538504  581406     46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505  581406     46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554  581408      85175                           NaN        20
# 538919  581422      23169                       smashed      -235
#
#                       date  unit_price  customer_id
# 622    2018-11-29 11:52:00         0.0          NaN
# 1970   2018-11-29 14:32:00         0.0          NaN
# ...

# %% [markdown]
# This orders look pretty strange. We could deep further - find description and price with stock code. But it's only 2475 orders - less that a percent of out data. And may be this orders wasn't finished because of some technical issue or they benn cancelled quickly. It's the issue for discuss with our team, of course. But in our investigation this rows can be dropped.

# %%
goods[goods['stock_code']=='22139']
# Out:
#          order stock_code                       description  quantity  \
# 106     536381      22139  RETROSPOT TEA SET CERAMIC 11 PC         23
# 622     536414      22139                               NaN        56
# 6392    536942      22139                            amazon        15
# 6885    536982      22139  RETROSPOT TEA SET CERAMIC 11 PC         10
# 7203    537011      22139                               NaN        -5
# ...        ...        ...                               ...       ...
# 538411  581405      22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 539531  581439      22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 540441  581486      22139  RETROSPOT TEA SET CERAMIC 11 PC          6
# 541387  581498      22139  RETROSPOT TEA SET CERAMIC 11 PC          2
# 541726  581570      22139  RETROSPOT TEA SET CERAMIC 11 PC          3
#
#                       date  unit_price  customer_id
# 106    2018-11-29 09:41:00        4.25      15311.0
# ...

# %%
goods[goods['order']=='581498']
# Out:
#          order stock_code                     description  quantity  \
# 541323  581498    15056bl         EDWARDIAN PARASOL BLACK         2
# 541324  581498      20669           RED HEART LUGGAGE TAG         3
# 541325  581498      20679           EDWARDIAN PARASOL RED         5
# 541326  581498      20712      JUMBO BAG WOODLAND ANIMALS         3
# 541327  581498      20713                  JUMBO BAG OWLS         8
# ...        ...        ...                             ...       ...
# 541536  581498     85099B         JUMBO BAG RED RETROSPOT         5
# 541537  581498     85099C  JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538  581498      85150   LADIES & GENTLEMEN METAL SIGN         1
# 541539  581498      85174               S/4 CACTI CANDLES         1
# 541540  581498        DOT                  DOTCOM POSTAGE         1
#
#                       date  unit_price  customer_id
# 541323 2019-12-07 10:26:00       12.46          NaN
# ...

# %%
#try to find out, may be there was a particular dates with corrupted data
print(len(no_customer_orders['date'].unique()))
print(no_customer_orders['date'].unique())
# Out:
# 3161
# ['2018-11-29T11:52:00.000000000' '2018-11-29T14:32:00.000000000'
#  '2018-11-29T14:33:00.000000000' ... '2019-12-07T10:03:00.000000000'
#  '2019-12-07T10:23:00.000000000' '2019-12-07T10:26:00.000000000']

# %% [markdown]
# We do not have any pattern here. Since we are analyzing products (not customers or, for example, cohorts), we will leave the customer_id column as it is. It still could be filled somehow - find a similar order may be on the same day and use its customer_id. That could work for cancelled orders or orders with technical mistakes. But it would require too much effort and wouldn't bring much value to our aim. So, let it be just like it is.

# %%
#dropping corrupted orders from initial df
goods=goods[~goods.index.isin(corrupted_orders.index)]
goods
# Out:
#          order stock_code                          description  quantity  \
# 0       536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365      71053                  WHITE METAL LANTERN         6
# 2       536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905  581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                       date  unit_price  customer_id
# ...

# %%
goods=goods.drop_duplicates(keep='first')
goods.sample(3)
# Out:
#           order stock_code                      description  quantity  \
# 24214   C538344      22867          HAND WARMER BIRD DESIGN       -12
# 164773   550666      22781            GUMBALL MAGAZINE RACK         2
# 289175   562233     84509A  SET OF 4 ENGLISH ROSE PLACEMATS         1
#
#                       date  unit_price  customer_id
# 24214  2018-12-08 14:32:00        2.10      13448.0
# 164773 2019-04-18 09:35:00        7.65      17719.0
# 289175 2019-08-01 14:54:00        3.75      14972.0

# %%
#check the df after †he preprocessing
print(goods.isna().sum())
print(goods.describe())
print(goods.info())
# Out:
# order               0
# stock_code          0
# description         0
# quantity            0
# date                0
# unit_price          0
# customer_id    132567
# dtype: int64
#             quantity     unit_price    customer_id
# count  534171.000000  534171.000000  401604.000000
# mean        9.942034       4.654077   15281.160818
# std       217.122291      97.457150    1714.006089
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13939.000000
# 50%         3.000000       2.100000   15145.000000
# 75%        10.000000       4.130000   16784.000000
# max     80995.000000   38970.000000   18287.000000
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534171 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order        534171 non-null  object
#  1   stock_code   534171 non-null  object
#  2   description  534171 non-null  object
# ...

# %% [markdown]
# #### Conclusion
# We've checked for missing values and duplicates. We had dropped some of the corrupted data and left just as it is some of the missing values.
# Maybe the reason is some kind of technical mistake, and we lost some data. Maybe it is the trouble during the collection or something else.

# %% [markdown]
# ### Looking for connections and relations in the data, plotting graphs

# %% [markdown]
# #### Sales per month

# %%
#extract month
goods['month']=goods['date'].dt.month
goods.sample(15)
# Out:
#          order stock_code                         description  quantity  \
# 244252  558475      23269    SET OF 2 CERAMIC CHRISTMAS TREES         2
# 92662   544202     85099C      JUMBO  BAG BAROQUE BLACK WHITE         1
# 437285  574281      23460               SWEETHEART WALL TIDY          2
# 521066  580311      22212          FOUR HOOK  WHITE LOVEBIRDS         6
# 336524  566361      22077              6 RIBBONS RUSTIC CHARM        12
# 192224  553393      22789   T-LIGHT HOLDER SWEETHEART HANGING         4
# 337311  566443      23079            TOADSTOOL BEDSIDE LIGHT          2
# 492291  578103      22725      ALARM CLOCK BAKELIKE CHOCOLATE         4
# 68833   541878      21216    SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 162695  550514      22521           CHILDS GARDEN TROWEL PINK        12
# 76233   542622      21094       SET/6 RED SPOTTY PAPER PLATES         1
# 226993  556813      22169    FAMILY ALBUM WHITE PICTURE FRAME         1
# ...

# %%
#calcaulate revenue
goods['total_price']=goods['quantity']*goods['unit_price']

# %%
#calcualte revenue per month and number of orders per month
sales_per_month=goods.groupby('month').agg({'total_price': 'sum', 'order': 'nunique'}).reset_index()
sales_per_month.columns=['month', 'revenue', 'number_of_orders']

# %%
sales_per_month.sort_values(by='revenue')
# Out:
#     month      revenue  number_of_orders
# 3       4   475027.041              1420
# 1       2   491357.550              1304
# 0       1   607854.450              1493
# 5       6   650449.140              1781
# 2       3   662566.860              1728
# 6       7   703302.801              1791
# 7       8   724046.080              1704
# 4       5   767802.050              2115
# 8       9   950182.892              2039
# 11     12   966703.990              2254
# 9      10  1131566.720              2560
# 10     11  1595147.380              3613

# %% [markdown]
# ##### Revenue graphs

# %%
#sns.lineplot(x=goods['month'], y=goods['total_price'])

# %%
plt.figure(figsize=(13, 9))
plt.title('Revenue overtime')
sns.lineplot(x=sales_per_month['month'], y=sales_per_month['revenue'])
plt.show()

# %%
plt.figure(figsize=(13, 9))
plt.title('Orders overtime')
sns.lineplot(x=sales_per_month['month'], y=sales_per_month['number_of_orders'])
plt.show()

# %%
#prepare for labeling barplot
plot=sales_per_month.groupby('month')['revenue'].sum().reset_index()
plot.head()
# Out:
#    month     revenue
# 0      1  607854.450
# 1      2  491357.550
# 2      3  662566.860
# 3      4  475027.041
# 4      5  767802.050

# %%
hue_label=sales_per_month['number_of_orders'].to_list()
hue_label
# Out:
# [1493, 1304, 1728, 1420, 2115, 1781, 1791, 1704, 2039, 2560, 3613, 2254]

# %%
plt.figure(figsize=(13, 9))
plt.title('Revenue overtime')
ax=sns.barplot(x=sales_per_month['month'], 
            y=sales_per_month['revenue'], hue=hue_label, hue_order=hue_label,
            dodge=False)
for index, row in plot.iterrows():
    ax.text(row.name,row.revenue, round(row.revenue,1), color='black', ha="center")
ax.legend(title='Number of orders')
plt.show()

# %%
plt.figure(figsize=(11,9))
plt.title('Scatter plot for price of the orders')
sns.set_theme(style="whitegrid")
ax=sns.scatterplot(x=goods['total_price'], y=goods['month'])
plt.show()

# %%
#average order and stats
goods['total_price'].describe()
# Out:
# count    534171.000000
# mean         18.207666
# std         381.533325
# min     -168469.600000
# 25%           3.750000
# 50%           9.900000
# 75%          17.570000
# max      168469.600000
# Name: total_price, dtype: float64

# %% [markdown]
# ##### Revenue stats with outliers

# %%
#first look at the statistics
goods['total_price'].describe()
# Out:
# count    534171.000000
# mean         18.207666
# std         381.533325
# min     -168469.600000
# 25%           3.750000
# 50%           9.900000
# 75%          17.570000
# max      168469.600000
# Name: total_price, dtype: float64

# %%
goods['total_price'].median()
# Out:
# 9.899999999999999

# %% [markdown]
# **Plotting graphs to see a distribution**

# %%
plt.figure()
sns.boxplot(goods['total_price'])
plt.title('Dictribution of the orders prices')
# Out:
# Text(0.5, 1.0, 'Dictribution of the orders prices')

# %% [markdown]
# There is negative orders - probably, these are returns. To get clear information about sales, we will analyze 'normal' orders without returned ones.

# %%
positive_orders=goods.query('total_price > 0')
positive_orders.sample(5)
# Out:
#          order stock_code                       description  quantity  \
# 291849  562524      22998      TRAVEL CARD WALLET KEEP CALM        24
# 188288  553021      47566                     PARTY BUNTING        60
# 311229  564230      22631          CIRCUS PARADE LUNCH BOX          3
# 290710  562417      22161  HEART DECORATION RUSTIC HANGING         11
# 159588  550347      84991       60 TEATIME FAIRY CAKE CASES        24
#
#                       date  unit_price  customer_id  month  total_price
# 291849 2019-08-03 13:28:00        0.42      15201.0      8        10.08
# 188288 2019-05-10 19:22:00        4.15      18172.0      5       249.00
# 311229 2019-08-22 10:22:00        4.13          NaN      8        12.39
# 290710 2019-08-02 16:32:00        0.79          NaN      8         8.69
# 159588 2019-04-16 09:33:00        0.55      14227.0      4        13.20

# %%
positive_orders.describe()
# Out:
#             quantity     unit_price    customer_id          month  \
# count  524878.000000  524878.000000  392692.000000  524878.000000
# mean       10.616600       3.922573   15287.843865       7.488975
# std       156.280031      36.093028    1713.539549       3.497527
# min         1.000000       0.001000   12346.000000       1.000000
# 25%         1.000000       1.250000   13955.000000       5.000000
# 50%         4.000000       2.080000   15150.000000       8.000000
# 75%        11.000000       4.130000   16791.000000      11.000000
# max     80995.000000   13541.330000   18287.000000      12.000000
#
#          total_price
# count  524878.000000
# mean       20.275399
# std       271.693566
# min         0.001000
# 25%         3.900000
# 50%         9.920000
# 75%        17.700000
# max    168469.600000

# %%
plt.figure(figsize=(9,7))
plt.title('Box plot for price of the orders')
sns.set_theme(style="whitegrid")
ax=sns.boxplot(x=positive_orders['total_price'])
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.title('Scatter plot for price of the orders')
sns.set_theme(style="whitegrid")
ax=sns.scatterplot(x=positive_orders['total_price'], y=positive_orders['month'])
plt.show()

# %% [markdown]
# #### Revenue stats without outliers

# %%
#looking for outliers
Q1 = positive_orders['total_price'].quantile(0.25)
Q3 = positive_orders['total_price'].quantile(0.75)
IQR = Q3 - Q1
print('IQR:',IQR,'Q1:', Q1,'Q3:', Q3)
# Out:
# IQR: 13.800000000000002 Q1: 3.9 Q3: 17.700000000000003

# %%
sns.boxplot(positive_orders['total_price'])
# Out:
# <AxesSubplot:xlabel='total_price'>

# %%
#using 3-sigma rule to get rid of outliers
sales_wo_outliers=positive_orders[~((positive_orders['total_price'] < (Q1 - 1.5 * IQR)) | (positive_orders['total_price'] > (Q3 + 1.5 * IQR)))]
sales_wo_outliers.sample(10)
# Out:
#          order stock_code                          description  quantity  \
# 283554  561774      23004            TRAVEL CARD WALLET PANTRY        24
# 233198  557442      22536           MAGIC DRAWING SLATE PURDEY         4
# 330705  565921      22110          BIRD HOUSE HOT WATER BOTTLE         6
# 427489  573387      22997        TRAVEL CARD WALLET UNION JACK         1
# 449402  575117      21892   TRADITIONAL WOODEN CATCH CUP GAME          1
# 183861  552670      22381               TOY TIDY PINK POLKADOT         1
# 62624   541508     72351a   SET/6 TURQUOISE BUTTERFLY T-LIGHTS         1
# 400780  571372      21744      SNOWFLAKE PORTABLE TABLE LIGHT          2
# 39627   539654      21916      SET 12 RETRO WHITE CHALK STICKS         6
# 17200   537690      22909  SET OF 20 VINTAGE CHRISTMAS NAPKINS        12
#
#                       date  unit_price  customer_id  month  total_price
# 283554 2019-07-27 12:41:00        0.42      16729.0      7        10.08
# ...

# %%
sales_wo_outliers['total_price'].describe()
# Out:
# count    482254.000000
# mean         10.541462
# std           8.318965
# min           0.001000
# 25%           3.400000
# 50%           8.400000
# 75%          15.900000
# max          38.400000
# Name: total_price, dtype: float64

# %%
sales_wo_outliers.describe()
# Out:
#             quantity     unit_price    customer_id          month  \
# count  482254.000000  482254.000000  356007.000000  482254.000000
# mean        6.263830       3.140320   15319.083423       7.492821
# std         8.944853       3.260993    1708.496247       3.501643
# min         1.000000       0.001000   12347.000000       1.000000
# 25%         1.000000       1.250000   13993.000000       5.000000
# 50%         3.000000       2.080000   15218.000000       8.000000
# 75%         9.000000       4.130000   16814.000000      11.000000
# max       900.000000      38.260000   18287.000000      12.000000
#
#          total_price
# count  482254.000000
# mean       10.541462
# std         8.318965
# min         0.001000
# 25%         3.400000
# 50%         8.400000
# 75%        15.900000
# max        38.400000

# %%
#the most popular number of items per order and most popular sum of the order
print(sales_wo_outliers['quantity'].mode())
print(sales_wo_outliers['total_price'].mode())
# Out:
# 0    1
# dtype: int64
# 0    15.0
# dtype: float64

# %%
plt.figure()
sns.boxplot(sales_wo_outliers['total_price'])
plt.title('Sales distribution without outliers')
plt.show()

# %% [markdown]
# #### Revenue graphs without outliers

# %%
sales_wo_outliers_per_month=sales_wo_outliers.groupby('month').agg({'total_price': 'sum', 'order': 'nunique'}).reset_index()
sales_wo_outliers_per_month.columns=['month', 'revenue', 'number_of_orders']

# %%
sales_wo_outliers_per_month.sort_values(by='revenue')
# Out:
#     month     revenue  number_of_orders
# 1       2  267102.890               967
# 3       4  279066.181              1079
# 5       6  331896.880              1348
# 2       3  335467.680              1288
# 0       1  338658.340              1115
# 7       8  356814.420              1271
# 6       7  371681.741              1374
# 4       5  397644.670              1571
# 8       9  485807.862              1581
# 11     12  503075.820              1704
# 9      10  610996.740              1960
# 10     11  805449.220              2830

# %%
hue_labels_out=sales_wo_outliers_per_month['number_of_orders'].to_list()
hue_labels_out
# Out:
# [1115, 967, 1288, 1079, 1571, 1348, 1374, 1271, 1581, 1960, 2830, 1704]

# %%
plt.figure(figsize=(13, 9))
plt.title('Revenue overtime, without outliers')
sns.lineplot(x=sales_wo_outliers_per_month['month'], y=sales_wo_outliers_per_month['revenue'])
plt.show()

# %%
plot_out=sales_wo_outliers_per_month.groupby('month')['revenue'].sum().reset_index()
plot_out.head()
#plot_out.iterrows
# Out:
#    month     revenue
# 0      1  338658.340
# 1      2  267102.890
# 2      3  335467.680
# 3      4  279066.181
# 4      5  397644.670

# %%
#plot a graph
plt.figure(figsize=(13, 9))
plt.title('Revenue overtime without outliers')
ax=sns.barplot(x=sales_wo_outliers_per_month['month'], 
            y=sales_wo_outliers_per_month['revenue'], 
            hue=hue_labels_out, 
            hue_order=hue_labels_out,
            dodge=False)
for index, row in plot_out.iterrows():
    ax.text(row.name,row.revenue, round(row.revenue,1), color='black', ha="center")
ax.legend(title='Number of orders')
plt.show()

# %% [markdown]
# #### Orders

# %%
goods.head()
# Out:
#     order stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                  date  unit_price  customer_id  month  total_price
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00
# 3 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 4 2018-11-29 08:26:00        3.39      17850.0     11        20.34

# %%
#number of orders per client
goods.groupby('customer_id')['order'].nunique().mean()
# Out:
# 5.07548032936871

# %%
#most often purchased clients
goods.groupby('customer_id')['order'].nunique().sort_values(ascending=False).head(15)
# Out:
# customer_id
# 14911.0    248
# 12748.0    224
# 17841.0    169
# 14606.0    128
# 13089.0    118
# 15311.0    118
# 12971.0     89
# 14527.0     86
# 13408.0     81
# 14646.0     77
# 16029.0     76
# 16422.0     75
# 14156.0     66
# 13798.0     63
# 18102.0     62
# Name: order, dtype: int64

# %%
#statistics of the clients
goods.groupby('customer_id')['order'].nunique().describe()
# Out:
# count    4372.000000
# mean        5.075480
# std         9.338754
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max       248.000000
# Name: order, dtype: float64

# %%
plt.figure(figsize=(7,9))
sns.boxplot(y=goods.groupby('customer_id')['order'].nunique(), showfliers=False)
plt.title ('Dictribution of orders per client')
plt.show()

# %%
#number of orders per month
orders_bar=goods.groupby('month')['order'].nunique().reset_index()
plt.figure(figsize=(7,5))
plt.title('Number of orders overtime')
ax=sns.barplot(x=orders_bar['month'], y=orders_bar['order'], dodge=False, orient='h')
plt.show()

# %%
#number of items per order
items_per_order=goods.groupby('order').agg({'total_price': 'sum', 'stock_code': 'nunique'}).reset_index()
items_per_order.columns=['order', 'order_price', 'number_of_items']
items_per_order
# Out:
#          order  order_price  number_of_items
# 0       536365       139.12                7
# 1       536366        22.20                2
# 2       536367       278.73               12
# 3       536368        70.05                4
# 4       536369        17.85                1
# ...        ...          ...              ...
# 23797  C581484   -168469.60                1
# 23798  C581490       -32.53                2
# 23799  C581499      -224.69                1
# 23800  C581568       -54.75                1
# 23801  C581569        -7.50                2
#
# [23802 rows x 3 columns]

# %%
items_per_order['number_of_items'].describe()
# Out:
# count    23802.000000
# mean        22.215654
# std         43.919451
# min          1.000000
# 25%          3.000000
# 50%         12.000000
# 75%         25.000000
# max       1110.000000
# Name: number_of_items, dtype: float64

# %%
plt.figure(figsize=(5,9))
plt.title('Distribution of the number of items per order')
sns.boxplot(y=items_per_order['number_of_items'])
plt.show()

# %%
print(items_per_order['number_of_items'].mean(),
items_per_order['number_of_items'].mode())
# Out:
# 22.21565414671036 0    1
# dtype: int64

# %%
print(items_per_order['number_of_items'].describe())
print('Average number of items per order',items_per_order['number_of_items'].mean())
# Out:
# count    23802.000000
# mean        22.215654
# std         43.919451
# min          1.000000
# 25%          3.000000
# 50%         12.000000
# 75%         25.000000
# max       1110.000000
# Name: number_of_items, dtype: float64
# Average number of items per order 22.21565414671036

# %% [markdown]
# Negative value could mean some kind of mistake or that orders was returned.

# %%
#get rid of returned orders
positive_orders=items_per_order[items_per_order['order_price'] > 0]
positive_orders.head()
# Out:
#     order  order_price  number_of_items
# 0  536365       139.12                7
# 1  536366        22.20                2
# 2  536367       278.73               12
# 3  536368        70.05                4
# 4  536369        17.85                1

# %%
print(positive_orders['number_of_items'].describe())
print('Average number of items per order',positive_orders['number_of_items'].mean())
# Out:
# count    19960.000000
# mean        26.033517
# std         46.982156
# min          1.000000
# 25%          6.000000
# 50%         15.000000
# 75%         29.000000
# max       1110.000000
# Name: number_of_items, dtype: float64
# Average number of items per order 26.033517034068137

# %% [markdown]
# ##### Item's quantity graphs

# %%
sns.displot(data=positive_orders['number_of_items'])
plt.title('Items per order')
plt.show()

# %%
#outliers
sns.boxplot(data=positive_orders['number_of_items'])
plt.title('Items per order')
plt.show()

# %%
Q1 = positive_orders['number_of_items'].quantile(0.25)
Q3 = positive_orders['number_of_items'].quantile(0.75)
IQR = Q3 - Q1
orders_out=positive_orders[~(positive_orders['number_of_items'] > (Q3))]
print(orders_out.sample(5))
print('shape',orders_out.shape)
print('IQR:',IQR,'Q1:', Q1,'Q3:', Q3)
# Out:
#         order  order_price  number_of_items
# 16285  573399       392.08               18
# 19060  579548       181.45               10
# 14120  568687        75.00                2
# 8051   554977       121.00               19
# 6009   550450        90.00                1
# shape (15163, 3)
# IQR: 23.0 Q1: 6.0 Q3: 29.0

# %%
#using 3-sigma rule to get rid of outliers
orders_wo_outliers=positive_orders[~(positive_orders['number_of_items'] > (Q3))]
orders_wo_outliers.sample(10)
# Out:
#         order  order_price  number_of_items
# 2075   541283       170.46               11
# 822    538154       294.01               21
# 8134   555164      3623.20               13
# 12527  565143         3.30                1
# 15931  572765      2251.20                3
# 12328  564563       301.92                4
# 665    537791       147.40                2
# 17165  575502       369.12               21
# 11572  562929       126.30                7
# 19884  581427       207.70               12

# %% [markdown]
# #### Item's quantity graphs without outliers

# %%
plt.figure(figsize=(13, 9))
plt.title('Items per order without outliers')
ax=sns.histplot(data=orders_wo_outliers['number_of_items'])
#ax.legend()
plt.show()

# %% [markdown]
# ### Conclusion
# With and without outliers November is the most profitable month (1 595 147,4 and 805 449,2) with 3613 and 1304 orders.
# The worst month with outliers is April with revenue 475027 with 1304 orders. The worst month without outliers is February, revenue was 267 102,9 with 963 orders.
#
# There were 25 900 orders in total. Part of them were returned or called off (orders with negative total sum). Reagrding the symmetry of negative and positive orders we can assume, that some orders had been made and returned or cancelled.
#
# In average one client made 5 orders, majority of clients made between 1 and 5 orders.
# Majority of the orders contains only 1 item. Average order contains 26 items.

# %% [markdown]
# ## Studing products

# %% [markdown]
# ### Categorize products

# %% [markdown]
# Research description of the products for groups (with lemmatization and clustering)

# %%
goods.head()
# Out:
#     order stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                  date  unit_price  customer_id  month  total_price
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00
# 3 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 4 2018-11-29 08:26:00        3.39      17850.0     11        20.34

# %%
#most profitable products including outliers
profatable_goods_outliers=goods.groupby(['stock_code', 'description'])['total_price'].sum().reset_index()
profatable_goods_outliers.sort_values(by='total_price').tail(10)
# Out:
#      stock_code                         description  total_price
# 3065      79321                       CHILLI LIGHTS     53746.66
# 3424      84879       ASSORTED COLOUR BIRD ORNAMENT     58792.42
# 1025      22086     PAPER CHAIN KIT 50'S CHRISTMAS      63715.24
# 4169       POST                             POSTAGE     66230.64
# 2032      23084                  RABBIT NIGHT LIGHT     66661.63
# 3633     85099B             JUMBO BAG RED RETROSPOT     92175.79
# 3654     85123A  WHITE HANGING HEART T-LIGHT HOLDER     97659.94
# 2882      47566                       PARTY BUNTING     98243.88
# 1343      22423            REGENCY CAKESTAND 3 TIER    164459.49
# 4166        DOT                      DOTCOM POSTAGE    206245.48

# %%
sales_wo_outliers.sample()
# Out:
#          order stock_code          description  quantity                date  \
# 185882  552829      82552  WASHROOM METAL SIGN         5 2019-05-09 13:42:00
#
#         unit_price  customer_id  month  total_price
# 185882        1.45      12748.0      5         7.25

# %%
profitatable_goods_no_outliers=sales_wo_outliers.groupby(['stock_code', 'description'])['total_price'].sum().reset_index()
profitatable_goods_no_outliers.sort_values(by='total_price').tail(10)
# Out:
#      stock_code                         description  total_price
# 2262      23298                      SPOTTY BUNTING     15717.32
# 1863      22960            JAM MAKING SET WITH JARS     16534.22
# 179       20725             LUNCH BAG RED RETROSPOT     17863.63
# 1366      22457     NATURAL SLATE HEART CHALKBOARD      18452.16
# 2851      47566                       PARTY BUNTING     18536.02
# 1620      22720   SET OF 3 CAKE TINS PANTRY DESIGN      18602.41
# 3383      84879       ASSORTED COLOUR BIRD ORNAMENT     18708.19
# 3584     85099B             JUMBO BAG RED RETROSPOT     22518.76
# 1333      22423            REGENCY CAKESTAND 3 TIER     25682.37
# 3605     85123A  WHITE HANGING HEART T-LIGHT HOLDER     29238.60

# %%
#number of unique products
goods['description'].nunique()
# Out:
# 4042

# %% [markdown]
# Lemmatize descriptions to gategorize the products

# %% [markdown]
# **We don't have categories from the shop or any information about products hierarchy. And the given data doesn't allow to automatize the further analisys. So, this task is half-manual. I will use lemmatizitaion and spacy to understand descriptions better. Then I will create some common-sence-based categories, using some examples from Wallmart or another popular shop, and tags for given data. Althought this approach isn't the most precise, categorizing would be useful and informative for the team.**

# %%
unique_desc_list=goods['description'].unique()
#str(goods['description'].unique())
#len(unique_desc)
#unique_desc=str(goods['description'].unique())
len(unique_desc_list)
# Out:
# 4042

# %%
unique_desc_str=''.join(unique_desc_list)
len(unique_desc_str)
# Out:
# 109543

# %%
#lemmatization of the descripions
wordnet_lemma = WordNetLemmatizer()
words = nltk.word_tokenize(str(unique_desc_str))
lemmas = [wordnet_lemma.lemmatize(w, pos='n') for w in words]
#lookinf for frequency of the words
print(Counter(lemmas))
# Out:
# Counter({'OF': 241, 'HEART': 187, 'VINTAGE': 150, 'PINK': 133, 'BAG': 113, 'GLASS': 113, 'CHRISTMAS': 109, 'RED': 108, 'SET': 102, 'BLUE': 100, 'METAL': 90, 'WALL': 84, 'ROSE': 84, 'T-LIGHT': 83, 'WITH': 81, 'AND': 80, ',': 80, 'CAKE': 74, '3': 72, 'IN': 71, 'BOX': 69, 'HANGING': 67, 'WHITE': 66, 'FLOWER': 65, 'RETROSPOT': 63, 'ART': 63, 'PAPER': 62, 'CANDLE': 60, 'GARDEN': 60, 'DESIGN': 58, '6': 55, 'TREE': 54, 'CARD': 53, '10': 52, '4': 52, 'GIFT': 51, 'EGG': 50, 'CUSHION': 50, 'CARDS': 49, 'TEA': 48, 'LOVE': 48, 'POLKADOT': 48, 'MINI': 47, 'W': 47, '12': 47, 'LARGE': 44, 'SILVER': 43, 'NECKLACE': 43, 'DECORATION': 41, 'STAR': 40, 'BLACK': 40, 'SIGN': 40, 'COVER': 39, "''": 39, 'GREEN': 38, 'BEAD': 38, 'BIRD': 37, 'SMALL': 37, 'GIRL': 34, 'KEY': 34, '&': 33, 'HOLDER': 33, 'CRYSTAL': 33, 'EARRINGS': 33, "'S": 32, 'MUG': 32, '2': 32, 'TIN': 32, 'TILE': 32, 'DOLLY': 30, 'CERAMIC': 30, 'WOODEN': 30, 'PHOTO': 30, 'BUTTERFLY': 30, 'EASTER': 30, 'WATER': 28, 'PAISLEY': 28, '``': 28, 'COLO
# ...

# %%
#different approach with spacy
nlp = spacy.load("en_core_web_md")

# %%
#find all the nouns in the descriptions
doc=nlp(unique_desc_str)
nouns=[]

for token in doc:
    if token.pos_ == 'NOUN':
        nouns.append(token.text)

print(nouns)
# Out:
# ['HANGING', 'HEART', 'T', 'LIGHT', 'FLAG', 'WATER', 'WOOLLY', 'T', 'LIGHT', 'POLKA', 'COLOUR', 'PLAYHOUSE', 'KITCHENFELTCRAFT', 'BOX', 'COLOUR', 'TEASPOONSBOX', 'VINTAGE', 'BOX', 'ALPHABET', 'BUILDING', 'BLOCK', 'WORDRECIPE', 'BOX', 'METAL', 'MAKING', 'SET', 'FASHIONYELLOW', 'BUILDING', 'BUNNIES', 'TAPE', 'INFLATABLE', 'POLITICAL', 'VINTAGE', 'HEADS', 'GAME', 'SET/2', 'RED', 'RETROSPOT', 'TEA', 'SNACK', 'BOXES', 'BOX', 'PARADE', 'GIRL', 'LIGHT', 'TEA', 'TOWELS', 'PARADE', 'SPACEBOYMINI', 'POSTAGEPAPER', 'CHAIN', 'KIT', "'S", 'REDRETRO', 'COFFEE', 'MUGVINTAGE', 'BILLBOARD', 'MUGVINTAGE', 'BILLBOARD', 'DRAWER', 'ANT', 'FINISHWOODEN', 'FINISHWOODEN', 'SEWING', 'LARGEHOT', 'WATER', 'TEA', 'HEART', 'T', 'LIGHT', 'BAG', 'PINK', 'WHITEJUMBO', 'PIECE', 'PIECE', 'PAPER', 'BOX', 'BOX', 'CAKE', 'CASESPACK', 'DINOSAUR', 'CAKE', 'CASESPACK', 'PINK', 'PAISLEY', 'CAKE', 'CASES60', 'TEATIME', 'COASTER', 'PERSONAL', 'DOORSIGNJUMBO', 'STORAGE', 'BAG', 'BAG', 'PINK', 'VINTAGE', 'PAISLEYJAM', 'TEA', 'SE
# ...

# %% [markdown]
# **Time to determine the categories**.
#
# I will split goods for a few catogories according to common sence, similar e-shops and our list of lemmas and nouns. To stop before diving too deep and creating too mane categories, I will put attention to the frequency of the words (Counter()).

# %%
#create categories and list of the words
decor = ['DECORATION', 'CANDLE', 'CUSHION', 'SWEETHEART', 'BUTTERFLY', 'TILE', 'T-LIGHT HOLDER', 'LANTERN', 'ALARM CLOCK', 'RIBBONS', 'FRAME' ,'SIGN', 'PARASOL', 'HEART']
accessories = ['EARRINGS', 'BAG', 'RING', 'PENDANT','HANDBAG', 'WALLET', 'PURSE', 'HAND WARMER']
kitchenware = ['KITCHEN','CAKE', 'TEA', 'GLASS', 'COFFEE', 'LUNCH', 'PLATE', 'MUG', 'BAKING', 'POT', 'DISH', 'BOTTLE', 'TEATIME', 'BOWL', 'CUTLERY', ]
furniture = ['HOOK', 'DRAWER', 'TABLE', 'DOOR', 'KNOB', 'MIRROR', 'RACK', 'HANGER', 'CABINET']
stationary = ['NOTEBOOK', 'PAPER', 'PEN', 'PENCIL', 'SHEET']
christmas = ['CHRISTMAS', 'XMAS', 'SANTA', 'CLAUS', 'GARLAND', 'PARTY']
toys_games = ['GIRLS', 'BOYS', 'PLAYHOUSE', 'DOLL', 'GAME', 'TOY', 'BLOCKS', 'BLOCK', 'PUZZLES' , 'PUZZLE', 'JIGSAW']
storage = ['BOX', 'BASKETS', 'BOXES', 'BASKET']

# %%
#function with looking for similarity
decor_nlp = []
accessories_nlp = []
kitchenware_nlp = []
furniture_nlp = []
stationary_nlp = []
christmas_nlp = []
toys_games_nlp = []

for item in decor:
    decor_nlp.append(nlp(item))

for item in accessories:
    accessories_nlp.append(nlp(item))

for item in kitchenware:
    kitchenware_nlp.append(nlp(item))

for item in furniture:
    furniture_nlp.append(nlp(item))

for item in stationary:
    stationary_nlp.append(nlp(item))

for item in toys_games:
    toys_games_nlp.append(nlp(item))

for item in christmas:
    christmas_nlp.append(nlp(item))

# %%
# descriptions=goods['description'].unique()
# descriptions=pd.DataFrame(descriptions, columns=['description'])
# descriptions
unique_desc_df=pd.DataFrame(goods['description'].unique(), columns=['description'])
unique_desc_df.sample(5)
# Out:
#                           description
# 3500     PACK OF 6 SMALL FRUIT STRAWS
# 47              EDWARDIAN PARASOL RED
# 2390             RETRO "TEA FOR ONE"
# 1337  3 GARDENIA MORRIS BOXED CANDLES
# 1225        MONEY BOX BISCUITS DESIGN

# %%
#items - manually generated list
def generate_auto_list(items):
  auto_list = []
  for noun in nouns:
      noun = nlp(noun)
      for item in items:
          if(item.similarity(noun) > 0.7):
              auto_list.append(noun.text)
  return list(set(auto_list))

# %%
decor_auto = generate_auto_list(decor_nlp)
accessories_auto = generate_auto_list(accessories_nlp)
kitchenware_auto = generate_auto_list(kitchenware_nlp)
furniture_auto = generate_auto_list(furniture_nlp)
stationary_auto = generate_auto_list(stationary_nlp)
christmas_auto = generate_auto_list(christmas_nlp)
toys_games_auto = generate_auto_list(toys_games_nlp)

# %%
def contains(list, row):
  for word in list:
    if word in row['description'] :
      return True
  return False

# %%
def assign_tags(row):
  tags = ''
  if contains(decor_auto,row):
    tags += ' decor'
  if contains(accessories_auto,row):
    tags += ' accessories'
  if contains(kitchenware_auto,row):
    tags += ' kitchenware'
  if contains(furniture_auto,row):
    tags += ' furniture'
  if contains(stationary_auto,row):
    tags += ' stationary'
  if contains(christmas_auto,row):
    tags += ' christmas'
  if contains(toys_games_auto,row):
    tags += ' toys_games'
  if len(tags) > 1:
    return tags
  else:
    return None

unique_desc_df['tags'] = unique_desc_df.apply(assign_tags, axis=1)
unique_desc_df.sample(5)
# Out:
#                             description                      tags
# 84    RED DRAWER KNOB ACRYLIC EDWARDIAN                 furniture
# 989             GOLD MINI TAPE MEASURE                       None
# 3845                DOLLY GIRL WALL ART                toys_games
# 1440        VINTAGE POST OFFICE CABINET                 furniture
# 2467   AQUA BERTIE GLASS BEAD BAG CHARM   accessories kitchenware

# %%
#join dataframes to put category into the each row (i.e. each product)
goods_categorized=goods.merge(unique_desc_df, how='left')
goods_categorized.sample(15)
# Out:
#           order stock_code                          description  quantity  \
# 430989   574249      21810     CHRISTMAS HANGING STAR WITH BELL         1
# 157977   550458      22995              TRAVEL CARD WALLET SUKI         1
# 417953   573151     72351A   SET/6 TURQUOISE BUTTERFLY T-LIGHTS         2
# 200653   554526      22326  ROUND SNACK BOXES SET OF4 WOODLAND          3
# 147165   549294      22189              CREAM HEART CARD HOLDER         2
# 374915   569714      21935                   SUKI  SHOULDER BAG         3
# 458995   576228      22209        WOOD STAMP SET HAPPY BIRTHDAY         1
# 54959    541002      22969         HOMEMADE JAM SCENTED CANDLES        12
# 143279   548893      22671       FRENCH LAUNDRY SIGN BLUE METAL         1
# 423360   573544      22726           ALARM CLOCK BAKELIKE GREEN         2
# 43065   C540152      22666      RECIPE BOX PANTRY YELLOW DESIGN        -1
# 516476   580527      22513             DOORSTOP FOOTBALL DESIGN         1
# ...

# %% [markdown]
# ### Category graphs

# %%
pie_chart=goods_categorized['tags'].value_counts(normalize=True) * 100
pie_chart=pie_chart.reset_index()
pie_chart=pie_chart.drop(pie_chart[pie_chart['tags'] < 3].index)
pie_chart.columns=['category', 'share']
pie_chart
# Out:
#                    category      share
# 0               kitchenware  24.259500
# 1                     decor  20.750012
# 2               accessories  11.248377
# 3                 furniture   5.672845
# 4         decor kitchenware   5.508419
# 5                toys_games   5.304241
# 6           decor christmas   5.273782
# 7                stationary   4.335492
# 8         decor accessories   3.096227
# 9   accessories kitchenware   3.094420

# %%
labels=pie_chart['category'].to_list()
pie_chart['share'].plot.pie(figsize=(10, 10),autopct='%1.1f%%', 
                   textprops={'fontsize': 12}, labels=labels,legend=None, ylabel='')
plt.title('Shares of different categories') 
plt.show()

# %% [markdown]
# ### Prices

# %%
goods_categorized['unit_price'].describe()
# Out:
# count    534171.000000
# mean          4.654077
# std          97.457150
# min      -11062.060000
# 25%           1.250000
# 50%           2.100000
# 75%           4.130000
# max       38970.000000
# Name: unit_price, dtype: float64

# %%
goods_categorized['unit_price'].mean()
# Out:
# 4.654077016530603

# %% [markdown]
# Negative prices could appear afte some kind of mistake. So, further we will get rid of him.

# %%
positive_prices=goods_categorized.query('unit_price > 0')
positive_prices['unit_price'].describe()
# Out:
# count    534129.000000
# mean          4.695864
# std          95.079189
# min           0.001000
# 25%           1.250000
# 50%           2.100000
# 75%           4.130000
# max       38970.000000
# Name: unit_price, dtype: float64

# %% [markdown]
# ### Prices graphs

# %%
plt.figure(figsize=(7,11))
sns.boxplot(y=goods_categorized['unit_price'])
plt.title('Prices')
handles=['Min price: {0:.3f}'.format(positive_prices['unit_price'].min()), 
        'Max price: {0:.3f}'.format(positive_prices['unit_price'].max()),
         'Median price: {0:.2f}'.format(positive_prices['unit_price'].median()),
        'Average price: {0:.2f}'.format(positive_prices['unit_price'].mean())]
plt.legend(labels=[handles])
plt.show()

# %%
#graph for the correct (=positive) prices
plt.figure(figsize=(7,11))
sns.boxplot(y=goods_categorized['unit_price'], showfliers=False)
plt.title('Prices without outliers')
legends=['Q1:{}'.format(goods_categorized['unit_price'].quantile(0.25)),
        'Q3:{}'.format(goods_categorized['unit_price'].quantile(0.75))]
plt.legend(labels=[legends],loc="upper right")
plt.show()

# %%
Q1_cat = goods_categorized['unit_price'].quantile(0.25)
Q3_cat = goods_categorized['unit_price'].quantile(0.75)
IQR_cat = Q3 - Q1
print(Q1_cat, Q3_cat, IQR_cat)
print(Q3_cat + 1.5 * IQR_cat)
# Out:
# 1.25 4.13 23.0
# 38.63

# %%
print('Revenue from the regular items:',
    goods_categorized.query('(@Q1_cat - 1.5 * @IQR_cat) <= unit_price <= (@Q3_cat + 1.5 * @IQR_cat)')['total_price'].sum(),
      'Revenue from the expensive items:',
    goods_categorized.query('unit_price > (@Q3_cat + 1.5 * @IQR_cat)')['total_price'].sum()
     )
# Out:
# Revenue from the regular items: 9744403.773999996 Revenue from the expensive items: 3727.2999999999884

# %% [markdown]
# ### Conclusion
# We don't have any information about assortment hierarchy. So we assign a tag to each item. Since the assortment is really big (more than 4000 items) this task should be automatized. There are still untagged items, but our algorithm can be improved if needed. In general, our approach will allow us to do the analysis and make some conclusions.
#
# We tagged items with these tags: kitchenware, decor, accessories, furniture, toys_games, stationery, and christmas. Some of the items belong to two or more categories which is okay and useful because can help people find the items they are looking for.
#
# The most profitable categories (=tags):
# - kitchenware	24.259500
# - decor	20.750012
# - accessories	11.248377
#
# The mean price per item is 4,65. The minimum price is 0.001000, maximum - 38970. The majority of items cost 1.25-4.13.
#
# Items with normal prices (not too expensive) brought 974403, the most expensive items brought 3727.

# %% [markdown]
# ## Study sales in terms of categories

# %%
revenue_per_category=goods_categorized.groupby(['tags', 'month'])['total_price'].sum().round(1).sort_values()
revenue_per_category=revenue_per_category.reset_index()
revenue_per_category
# Out:
#                             tags  month  total_price
# 0     decor christmas toys_games     10          1.6
# 1                      christmas      8          5.9
# 2          accessories furniture      7          7.1
# 3          accessories furniture      2          7.4
# 4          accessories furniture      8          8.2
# ..                           ...    ...          ...
# 406                        decor     10     198098.2
# 407                  kitchenware     10     202331.4
# 408                        decor     11     234671.0
# 409                  kitchenware     12     237677.3
# 410                  kitchenware     11     293973.3
#
# [411 rows x 3 columns]

# %%
#quantile to make calculations more precise and less human-depending
revenue_per_category['total_price'].quantile(0.75)
# Out:
# 14698.650000000001

# %% [markdown]
# #### Most profitable categories

# %%
profitable_categories=revenue_per_category.query('total_price > total_price.quantile(0.75)')
profitable_categories.sort_values(by='total_price')
# Out:
#                              tags  month  total_price
# 308               decor christmas      1      14778.6
# 309                    stationary      5      15411.7
# 310   decor kitchenware christmas      6      15851.5
# 311                    toys_games      4      15889.2
# 312             decor accessories      5      15953.4
# ..                            ...    ...          ...
# 406                         decor     10     198098.2
# 407                   kitchenware     10     202331.4
# 408                         decor     11     234671.0
# 409                   kitchenware     12     237677.3
# 410                   kitchenware     11     293973.3
#
# [103 rows x 3 columns]

# %% [markdown]
# #### Graph: revenue form the most profitable categories per month

# %%
revenue_per_category_wmonth=goods_categorized.groupby(['tags','month'])['total_price'].sum().reset_index().query('total_price > total_price.quantile(0.75)')
revenue_per_category_wmonth
# Out:
#              tags  month  total_price
# 0     accessories      1     38768.49
# 1     accessories      2     28564.14
# 2     accessories      3     55565.30
# 3     accessories      4     35657.66
# 4     accessories      5     76940.47
# ..            ...    ...          ...
# 406    toys_games      8     28341.10
# 407    toys_games      9     30358.41
# 408    toys_games     10     40320.63
# 409    toys_games     11     51931.80
# 410    toys_games     12     28049.30
#
# [103 rows x 3 columns]

# %%
revenue_per_category_wmonth_pivoted=revenue_per_category_wmonth.pivot(index='month', columns='tags', values='total_price').reset_index()
revenue_per_category_wmonth_pivoted
# Out:
# tags  month   accessories   accessories kitchenware       decor  \
# 0         1      38768.49                  20678.58  117540.590
# 1         2      28564.14                       NaN   80898.700
# 2         3      55565.30                  21179.01   90440.270
# 3         4      35657.66                       NaN   73386.641
# 4         5      76940.47                  22133.89  107500.530
# 5         6      64691.69                  19928.26   86596.870
# 6         7      70634.52                  19620.12  111647.241
# 7         8      87640.16                  22816.12  110978.230
# 8         9      80519.36                  21601.34  158929.171
# 9        10      89587.64                  25541.72  198098.210
# 10       11     136711.86                  33903.41  234670.970
# 11       12      54576.82                  19369.21  171793.220
#
# tags   decor accessories   decor christmas   decor kitchenware  \
# 0                    NaN          14778.56            33489.95
# ...

# %%
#plot a graph
cats=revenue_per_category_wmonth['tags'].unique()
print(cats)

plt.figure()
revenue_per_category_wmonth_pivoted.plot(kind='line',x='month',y=cats, 
                                         figsize=(17,11), cmap='brg')
plt.xlabel("Month")
plt.ylabel('Revenue')
plt.title('Revenue from the different tags')
plt.show()
# Out:
# [' accessories' ' accessories kitchenware' ' decor' ' decor accessories'
#  ' decor christmas' ' decor kitchenware' ' decor kitchenware christmas'
#  ' furniture' ' kitchenware' ' stationary' ' toys_games']

# %%
list_=profitable_categories['tags'].to_list()

# %%
#revenue_per_category_wmonth_pivoted.drop(['tags'], axis=1)
revenue_per_category_wmonth_pivoted.drop(
    columns=[' accessories kitchenware', ' decor kitchenware', ' decor kitchenware christmas',
             ' decor accessories', ' decor christmas']
)
# Out:
# tags  month   accessories       decor   furniture   kitchenware   stationary  \
# 0         1      38768.49  117540.590    32355.51     143138.14          NaN
# 1         2      28564.14   80898.700    24773.67     105138.17          NaN
# 2         3      55565.30   90440.270    31298.89     122794.58     19185.42
# 3         4      35657.66   73386.641    22071.16      89816.48     20574.65
# 4         5      76940.47  107500.530    45550.53     151747.48     15411.74
# 5         6      64691.69   86596.870    48703.48     126978.07          NaN
# 6         7      70634.52  111647.241    44540.97     150390.66          NaN
# 7         8      87640.16  110978.230    32995.10     143264.37          NaN
# 8         9      80519.36  158929.171    72998.61     195621.36     21854.94
# 9        10      89587.64  198098.210    57636.48     202331.39     31976.57
# 10       11     136711.86  234670.970    61938.89     293973.25     66949.27
# ...

# %% [markdown]
# ## Study market baskets
# Wich products are bought repeteadly, how often clients make second orders, etc.

# %% [markdown]
# To look for combinations of the products I will use Apriori algorythm.

# %%
goods.head(3)
# Out:
#     order stock_code                         description  quantity  \
# 0  536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                 WHITE METAL LANTERN         6
# 2  536365     84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#                  date  unit_price  customer_id  month  total_price
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00

# %% [markdown]
# ### Prepare the data for apriory algorythm

# %%
#delete spaces from descriptions
goods['description'] = goods['description'].str.strip()

# %%
#looking for corrupted or abnormal stock_codes
str(goods['stock_code'].unique().tolist())
# Out:
# "['85123A', '71053', '84406B', '84029G', '84029E', '22752', '21730', '22633', '22632', '84879', '22745', '22748', '22749', '22310', '84969', '22623', '22622', '21754', '21755', '21777', '48187', '22960', '22913', '22912', '22914', '21756', '22728', '22727', '22726', '21724', '21883', '10002', '21791', '21035', '22326', '22629', '22659', '22631', '22661', '21731', '22900', '21913', '22540', '22544', '22492', 'POST', '22086', '20679', '37370', '21871', '21071', '21068', '82483', '82486', '82482', '82494L', '21258', '22114', '21733', '22386', '85099C', '21033', '20723', '84997B', '84997C', '21094', '20725', '21559', '22352', '21212', '21975', '21977', '84991', '84519A', '85183B', '85071B', '21931', '21929', '22961', '22139', '84854', '22411', '82567', '21672', '22774', '22771', '71270', '22262', '22637', '21934', '21169', '21166', '21175', '37444A', '37444C', '22083', '84971S', '47580', '22261', '84832', '22644', '21533', '21557', '15056BL', '15056N', '22646', '22176', '22438', '22778',
# ...

# %%
#drop rows with abnornal stock codes
abnormal_stock_codes=['DOT', 'CRUK', 'B', 'D', 'BANK CHARGES', 'POST']
df_for_dropping=goods.query('stock_code in @abnormal_stock_codes')
goods_aprioi=goods[~goods.index.isin (df_for_dropping.index)]
goods_aprioi
# Out:
#          order stock_code                          description  quantity  \
# 0       536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365      71053                  WHITE METAL LANTERN         6
# 2       536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905  581587      22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906  581587      23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907  581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587      22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                       date  unit_price  customer_id  month  total_price
# ...

# %% [markdown]
# Some of the values in the column 'order' contains letter 'C'. We don't know it's meaning (credit? cancelled?).

# %%
#how many c-orders do we have?
len(goods_aprioi[goods_aprioi['order'].str.contains('C')])/len(goods_aprioi)
# Out:
# 0.016926057972594295

# %% [markdown]
# 1,7% of the c-orders. Not too many, so we cah drop them.

# %%
goods_aprioi['order']=goods_aprioi['order'].astype(str)
goods_aprioi=goods_aprioi[~goods_aprioi['order'].str.contains('C')]
goods_aprioi.head(5)
# Out:
#     order stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                  date  unit_price  customer_id  month  total_price
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00
# 3 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 4 2018-11-29 08:26:00        3.39      17850.0     11        20.34

# %%
goods_basket = goods_aprioi.groupby(['order', 'description'])['quantity'].sum().unstack()#.reset_index()
goods_basket = goods_basket.reset_index()  
goods_basket.sample(10)
# Out:
# description   order  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# 15795        572613                    NaN                      NaN
# 3473         544676                    NaN                      NaN
# 4135         546134                    NaN                      NaN
# 17711        576849                    NaN                      NaN
# 10865        561360                    NaN                      NaN
# 9127         557469                    NaN                      NaN
# 9825         559041                    NaN                      NaN
# 10107        559679                    NaN                      NaN
# 16420        574039                    NaN                      NaN
# 1341         539417                    NaN                      NaN
#
# description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 15795                           NaN                         NaN
# 3473                            NaN                         NaN
# ...

# %%
goods_basket=goods_basket.set_index('order')
goods_basket=goods_basket.fillna(0)
goods_basket.head()
# Out:
# description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# order
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# order
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# order
# 536365                             0.0                        0.0
# ...

# %%
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
goods_basket=goods_basket.applymap(my_encode_units)
goods_basket.head()
# Out:
# description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# order
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
#
# description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# order
# 536365                            0                           0
# 536366                            0                           0
# 536367                            0                           0
# 536368                            0                           0
# 536369                            0                           0
#
# description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# order
# 536365                               0                          0
# ...

# %% [markdown]
# ### Implementing Apriori

# %%
#frequent itemsets
frequent_itemsets = apriori(goods_basket, min_support=0.007, use_colnames=True, low_memory = True)

# %%
#generating rules
apriori_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
len(apriori_rules)
# Out:
# 15806

# %%
#viewing top 30 rules
apriori_rules=apriori_rules.drop(['leverage', 'conviction'], axis=1)
apriori_rules.head(20)
# Out:
#                               antecedents  \
# 0   (12 PENCILS SMALL TUBE RED RETROSPOT)
# 1           (12 PENCILS SMALL TUBE SKULL)
# 2     (SET OF 3 BUTTERFLY COOKIE CUTTERS)
# 3    (3 PIECE SPACEBOY COOKIE CUTTER SET)
# 4              (3 STRIPEY MICE FELTCRAFT)
# 5            (FELTCRAFT 6 FLOWER FRIENDS)
# 6              (3 STRIPEY MICE FELTCRAFT)
# 7            (FELTCRAFT BUTTERFLY HEARTS)
# 8           (4 TRADITIONAL SPINNING TOPS)
# 9     (TRADITIONAL WOODEN CATCH CUP GAME)
# 10     (TRADITIONAL WOODEN SKIPPING ROPE)
# 11          (4 TRADITIONAL SPINNING TOPS)
# 12          (4 TRADITIONAL SPINNING TOPS)
# 13    (VINTAGE HEADS AND TAILS CARD GAME)
# 14                   (VINTAGE SNAP CARDS)
# 15          (4 TRADITIONAL SPINNING TOPS)
# 16        (6 GIFT TAGS VINTAGE CHRISTMAS)
# 17           (6 GIFT TAGS 50'S CHRISTMAS)
# 18       (PAPER CHAIN KIT 50'S CHRISTMAS)
# 19           (6 GIFT TAGS 50'S CHRISTMAS)
#
#                               consequents  antecedent support  \
# ...

# %%
#stats about metrics will help to filter the rules
apriori_rules.describe()
# Out:
#        antecedent support  consequent support       support    confidence  \
# count        15806.000000        15806.000000  15806.000000  15806.000000
# mean             0.036846            0.036846      0.009061      0.366329
# std              0.024369            0.024369      0.002708      0.231402
# min              0.007295            0.007295      0.007044      0.062057
# 25%              0.016351            0.016351      0.007496      0.172924
# 50%              0.031646            0.031646      0.008201      0.291919
# 75%              0.051922            0.051922      0.009509      0.529825
# max              0.113504            0.113504      0.041507      0.993671
#
#                lift
# count  15806.000000
# mean      14.827887
# std       16.674031
# min        1.078975
# 25%        5.874234
# 50%       10.032865
# 75%       16.336870
# max       94.065594

# %%
#filter the rules to get an example for recommendations
apriori_strong_rules=apriori_rules.query('confidence >= 0.29 & lift >= 10')
apriori_strong_rules.columns=['antecedents', 'consequents', 'antecedent_support',
                             'consequent_support', 'support', 'confidence', 'lift']
apriori_strong_rules=apriori_strong_rules.drop(columns=['antecedent_support', 'consequent_support']).head(40)
apriori_strong_rules.sort_values(by='lift', ascending=False)
# Out:
#                                antecedents  \
# 218      (AIRLINE BAG VINTAGE JET SET RED)
# 219         (AIRLINE BAG VINTAGE TOKYO 78)
# 16         (6 GIFT TAGS VINTAGE CHRISTMAS)
# 17            (6 GIFT TAGS 50'S CHRISTMAS)
# 20              (ROLL WRAP 50'S CHRISTMAS)
# 21            (6 GIFT TAGS 50'S CHRISTMAS)
# 23           (ROLL WRAP VINTAGE CHRISTMAS)
# 22         (6 GIFT TAGS VINTAGE CHRISTMAS)
# 0    (12 PENCILS SMALL TUBE RED RETROSPOT)
# 1            (12 PENCILS SMALL TUBE SKULL)
# 9      (TRADITIONAL WOODEN CATCH CUP GAME)
# 8            (4 TRADITIONAL SPINNING TOPS)
# 116      (60 CAKE CASES DOLLY GIRL DESIGN)
# 117       (PACK OF 60 SPACEBOY CAKE CASES)
# 11           (4 TRADITIONAL SPINNING TOPS)
# 10      (TRADITIONAL WOODEN SKIPPING ROPE)
# 131      (60 CAKE CASES VINTAGE CHRISTMAS)
# 130  (SET OF 20 VINTAGE CHRISTMAS NAPKINS)
# 223         (AIRLINE BAG VINTAGE TOKYO 78)
# 7             (FELTCRAFT BUTTERFLY HEARTS)
# 6               (3 STRIPEY MICE FELTCRAFT)
# ...

# %%
pd.options.display.max_colwidth
pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Statistical hypotheses

# %% [markdown]
# 1. Is there a correlation between season of the year and popular products
# 2. Is the average revenue from the clients who purchased once more than the average revenue from the clients who made multiple orders.

# %%
goods_categorized.sample(3)
# Out:
#          order stock_code                    description  quantity  \
# 364171  569005      22138  BAKING SET 9 PIECE RETROSPOT          3
# 24707   538361      22502     PICNIC BASKET WICKER SMALL         2
# 470567  577051      22151      PLACE SETTING WHITE HEART         1
#
#                       date  unit_price  customer_id  month  total_price  \
# 364171 2019-09-27 18:30:00        4.95      16268.0      9        14.85
# 24707  2018-12-08 16:36:00        5.95      17757.0     12        11.90
# 470567 2019-11-15 14:02:00        0.42      14034.0     11         0.42
#
#                 tags
# 364171   kitchenware
# 24707           None
# 470567         decor

# %%
#looking for popular products
popular_products=goods_categorized.groupby(['stock_code','description', 'month']).agg({'total_price': 'sum', 'quantity': 'sum', 'order': 'nunique',}).reset_index()
#delete 'DOTCOM' orders
popular_products=popular_products.drop(popular_products[popular_products['description']=='DOTCOM POSTAGE'].index)
#вrop unnecessary columns and look at the result
popular_products=popular_products.sort_values(by='total_price', ascending=False)
popular_products.drop(columns=['month', 'order']).head(15)
# Out:
#       stock_code                         description  total_price  quantity
# 13934      22502      PICNIC BASKET WICKER 60 PIECES     39619.50        61
# 19947      23084                  RABBIT NIGHT LIGHT     34499.58     14800
# 9745       22086     PAPER CHAIN KIT 50'S CHRISTMAS      30734.28      8476
# 13096      22423            REGENCY CAKESTAND 3 TIER     28387.07      2087
# 24287      47566                       PARTY BUNTING     19744.01      3691
# 13095      22423            REGENCY CAKESTAND 3 TIER     16662.96      1295
# 29887     85123A  WHITE HANGING HEART T-LIGHT HOLDER     16285.07      5931
# 29897     85123A  WHITE HANGING HEART T-LIGHT HOLDER     16243.88      5704
# 24289      47566                       PARTY BUNTING     15483.11      2853
# 10857      22197                      POPCORN HOLDER     14914.23     13330
# 13087      22423            REGENCY CAKESTAND 3 TIER     14605.29      1119
# ...

# %%
print(popular_products['quantity'].describe())
print(popular_products['quantity'].quantile(0.95))
# Out:
# count    33100.000000
# mean       160.424199
# std        390.589062
# min      -5802.000000
# 25%          7.000000
# 50%         37.000000
# 75%        150.000000
# max      14800.000000
# Name: quantity, dtype: float64
# 710.0

# %%
most_popular_products=popular_products.query('quantity >= 710')
most_popular_products
# Out:
#       stock_code                      description  month  total_price  \
# 19947      23084               RABBIT NIGHT LIGHT     11     34499.58
# 9745       22086  PAPER CHAIN KIT 50'S CHRISTMAS      11     30734.28
# 13096      22423         REGENCY CAKESTAND 3 TIER     12     28387.07
# 24287      47566                    PARTY BUNTING      5     19744.01
# 13095      22423         REGENCY CAKESTAND 3 TIER     11     16662.96
# ...          ...                              ...    ...          ...
# 366        16045       POPART WOODEN PENCILS ASST      6        48.00
# 545        16218       CARTOON  PENCIL SHARPENERS      9        43.20
# 368        16045       POPART WOODEN PENCILS ASST      8        36.00
# 371        16045       POPART WOODEN PENCILS ASST     11        36.00
# 33064          M                           Manual     12        -7.54
#
#        quantity  order
# 19947     14800    502
# 9745       8476    425
# 13096      2087    210
# 24287      3691    255
# ...

# %%
most_popular_products_by_month=most_popular_products.groupby(['month', 'description', 'stock_code'])['quantity'].sum().reset_index()
most_popular_products_by_month
# Out:
#       month                         description stock_code  quantity
# 0         1         60 TEATIME FAIRY CAKE CASES      84991      1177
# 1         1      72 SWEETHEART FAIRY CAKE CASES      84992      1553
# 2         1     ANTIQUE SILVER TEA GLASS ETCHED      84946       897
# 3         1       ASSORTED COLOUR BIRD ORNAMENT      84879      2275
# 4         1                 BROCADE RING PURSE       17003      3289
# ...     ...                                 ...        ...       ...
# 1652     12       WHITE SKULL HOT WATER BOTTLE       21479      1617
# 1653     12   WOOD BLACK BOARD ANT WHITE FINISH      82484      1666
# 1654     12  WOODEN STAR CHRISTMAS SCANDINAVIAN      22578      1080
# 1655     12              WOODLAND CHARLOTTE BAG      20719      1351
# 1656     12   WORLD WAR 2 GLIDERS ASSTD DESIGNS      84077      3004
#
# [1657 rows x 4 columns]

# %% [markdown]
# ### The average revenue from the clients who purchased once doesn't differs from the average revenue from the clients who made multiple orders.

# %%
goods.head(3)
# Out:
#     order stock_code                         description  quantity  \
# 0  536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                 WHITE METAL LANTERN         6
# 2  536365     84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#                  date  unit_price  customer_id  month  total_price
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00

# %%
#stats for the quantity of orders per client
customers=sales_wo_outliers.groupby('customer_id').agg({'total_price': 'sum', 'order': 'nunique'})
customers.query('order == 1').describe()
# Out:
#        total_price   order
# count  1480.000000  1480.0
# mean    250.854534     1.0
# std     252.734884     0.0
# min       1.900000     1.0
# 25%     112.222500     1.0
# 50%     190.225000     1.0
# 75%     320.607500     1.0
# max    3938.410000     1.0

# %%
plt.figure()
plt.title('Ditribution of the revenue per client')
sns.distplot(customers['total_price'])
plt.show()

# %%
plt.figure()
plt.title('Ditribution of the orders per client')
sns.distplot(customers['order'])
# Out:
# <AxesSubplot:title={'center':'Ditribution of the orders per client'}, xlabel='order', ylabel='Density'>

# %%
#looking for outliers
Q1 = customers['order'].quantile(0.25)
Q3 = customers['order'].quantile(0.75)
IQR = Q3 - Q1
print('IQR:',IQR,'Q1:', Q1,'Q3:', Q3)
# Out:
# IQR: 3.0 Q1: 1.0 Q3: 4.0

# %%
#looking for outliers
Q1 = customers['total_price'].quantile(0.25)
Q3 = customers['total_price'].quantile(0.75)
IQR = Q3 - Q1
print('IQR:',IQR,'Q1:', Q1,'Q3:', Q3)
# Out:
# IQR: 902.1499999999996 Q1: 207.8 Q3: 1109.9499999999996

# %%
only_order_customers=customers.query('order == 1')
several_order_customers=customers.query('order > 1')
print(several_order_customers.head(), '\n', only_order_customers.head())
# Out:
#              total_price  order
# customer_id
# 12347.0          3056.42      7
# 12348.0           111.08      3
# 12352.0          1385.74      7
# 12356.0           668.13      3
# 12358.0           142.66      2
#               total_price  order
# customer_id
# 12349.0          1105.40      1
# 12350.0           294.40      1
# 12353.0            49.20      1
# 12354.0           930.68      1
# 12355.0           224.80      1

# %%
#sorted(several_order_customers['total_price'].unique())

# %%
#check the equality of the variances with Levine test
# Null hypothesis - variances are the same, Alt hypothesis - variances are different
#Alpha = 0,05
statistic, pvalue = st.levene(only_order_customers['total_price'], several_order_customers['total_price'])
statistic, pvalue
# Out:
# (169.755162935908, 4.566489526464422e-38)

# %% [markdown]
# The variances are different.

# %%
#check the normality of the samples
#Null hypothesis - distribotion is normal, Alt hypothesis - distribotion is not normal
#Alpha = 0,05

result_one_order=st.shapiro(only_order_customers['total_price'])
result_several_orders=st.shapiro(several_order_customers['total_price'])
print(result_one_order,result_several_orders)
# Out:
# ShapiroResult(statistic=0.6383321285247803, pvalue=0.0) ShapiroResult(statistic=0.34241974353790283, pvalue=0.0)

# %% [markdown]
# Since the p-values are lees than alpha we reject null hypothesis - distributions of the samples are not normal. So we have to run Mann Whitney U test.

# %%
#Null hypothesis - The average revenue from the clients who purchased once doesn't differs 
#from the average revenue from the clients who made multiple orders.

alpha = 0.05 

statistic, pvalue = st.mannwhitneyu(only_order_customers['total_price'], several_order_customers['total_price'], alternative = 'less')

print('p-value:', pvalue)

if pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value: 0.0
# We reject the null hypothesis

# %% [markdown]
# This means that there is difference bitween average revenue from different groups of clients.

# %% [markdown]
# ### Is the average revenue from the orders with at least one item from kitchenware differs than the average revenue from the orders with at least one iten from decor

# %% [markdown]
# This hypothesis will help us to determine driver of high sales - is it decor or kitchenware.

# %%
goods_categorized.head()
# Out:
#     order stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                  date  unit_price  customer_id  month  total_price  \
# 0 2018-11-29 08:26:00        2.55      17850.0     11        15.30
# 1 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 2 2018-11-29 08:26:00        2.75      17850.0     11        22.00
# 3 2018-11-29 08:26:00        3.39      17850.0     11        20.34
# 4 2018-11-29 08:26:00        3.39      17850.0     11        20.34
#
#                tags
# 0             decor
# 1              None
# 2   decor furniture
# 3       kitchenware
# 4             decor

# %%
goods_grouped_by_order=goods_categorized.groupby(['order', 'tags'])['total_price'].sum().reset_index()
goods_grouped_by_order.head()
# Out:
#     order              tags  total_price
# 0  536365             decor        35.64
# 1  536365   decor furniture        22.00
# 2  536365       kitchenware        45.84
# 3  536366       accessories        22.20
# 4  536367             decor        31.80

# %%
#goods_grouped_by_order.query("tags.str.contains('decor')")
decor=goods_grouped_by_order[goods_grouped_by_order['tags'].str.contains('decor')]
#get rid of the orders with decor and kitchenware to make samples independent
decor=decor[~decor['tags'].str.contains('kitchenware')]
#[~goods_aprioi['order'].str.contains('C')]
kitchenware=goods_grouped_by_order[goods_grouped_by_order['tags'].str.contains('kitchenware')]
kitchenware=kitchenware[~kitchenware['tags'].str.contains('decor')]
decor
# Out:
#           order                           tags  total_price
# 0        536365                          decor        35.64
# 1        536365                decor furniture        22.00
# 4        536367                          decor        31.80
# 11       536370                          decor       225.00
# 12       536370   decor accessories toys_games        17.00
# ...         ...                            ...          ...
# 118658  C581235                          decor        -1.65
# 118666  C581390                          decor        -7.65
# 118667  C581393                decor christmas       -12.75
# 118668  C581409                          decor        -2.95
# 118687  C581569                          decor        -1.25
#
# [37311 rows x 3 columns]

# %%
#plot a dictribution to check the normality of the data
plt.figure()
sns.displot(kitchenware['total_price'], kde=True)
sns.displot(decor['total_price'], kde=True)
plt.title('Distirbution of total price for the orders with kitchenware and decor item(s)')
plt.show()

# %% [markdown]
# So,the distribution doesn't look normal.

# %%
#check the equality of the variances with Levine test
# Null hypothesis - variances are the same, Alt hypothesis - variances are different
#Alpha = 0,05
statistic, pvalue = st.levene(kitchenware['total_price'], decor['total_price'])
statistic, pvalue
# Out:
# (114.81748094317837, 9.058502952428965e-27)

# %% [markdown]
# Since the plots doesn't look normal distributed and variance aren't equal we have to run Mann Whitney U test.

# %%
#Null hypothesis - the average revenue from the orders with at least one kitchenware item is equal to
#the average revenue from the orders with at least one decor item

alpha = 0.05 

statistic, pvalue = st.mannwhitneyu(kitchenware['total_price'], decor['total_price'], alternative = 'less')

print('p-value:', pvalue)

if pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value: 1.0
# We can't reject the null hypothesis

# %% [markdown]
# Now we know that there is no difference between the average revenue from the orders with at least one kitchenware item and the average revenue from the orders with at least one decor item.

# %% [markdown]
# ## General conclusions

# %% [markdown]
# **1. General**
#
# We've been given a table with 541909 rows and 7 columns.
#
# - InvoiceNo    541909 non-null  object
# - StockCode    541909 non-null  object
# - Description  540455 non-null  object
# - Quantity     541909 non-null  int64
# - InvoiceDate  541909 non-null  object
# - UnitPrice    541909 non-null  float64
# - CustomerID   406829 non-null  float64
#
# We've checked for missing values and duplicates. We changed data types in the InvoiceDate column, dropped some of the corrupted data and left just as it is some of the missing values.
# Maybe the reason is some kind of technical mistake and we lost some data. Maybe it is the trouble during the collection or something else.

# %% [markdown]
# **2. Sales investigation**
#
# With and without outliers November is the most profitable month (1 595 147,4 and 805 449,2) with 3613 and 1304 orders.
# The worst month with outliers is April - with revenue 475027 and 1304 orders. The worst month without outliers is February - the revenue was 267 102,9 with 963 orders.

# %% [markdown]
# Here is the graph with revenue and number of orders per month.

# %%
plt.figure(figsize=(13, 9))
plt.title('Revenue overtime')
ax=sns.barplot(x=sales_per_month['month'], 
            y=sales_per_month['revenue'], hue=hue_label, hue_order=hue_label,
            dodge=False)
for index, row in plot.iterrows():
    ax.text(row.name,row.revenue, round(row.revenue,1), color='black', ha="center")
ax.legend(title='Number of orders')
plt.show()

# %% [markdown]
# **3. Orders, prices**
#
# There were 25 900 orders in total. Part of them was returned or called off (orders with a negative total sum). Regarding the symmetry of negative and positive orders, we can assume that some orders had been made and then returned or cancelled.
#
# On average one client made 5 orders, majority of clients made between 1 and 5 orders.
# The majority of the orders contain only 1 item.
# The average order contains 26 items.

# %%
plt.figure(figsize=(13, 9))
plt.title('Items per order without outliers')
ax=sns.histplot(data=orders_wo_outliers['number_of_items'])
#ax.legend()
plt.show()

# %% [markdown]
# **4. Assortment, tags**
#
# We don't have any information about assortment hierarchy. So we assign a tag to each item. Since the assortment is really big (more than 4000 items) this task should be automatized. There are still untagged items, but our algorithm can be improved if needed. In general, our approach will allow us to do the analysis and make some conclusions.
#
# We tagged items with these tags: kitchenware, decor, accessories, furniture, toys_games, stationery, christmas. Some of the items belong to two or more categories which are okay and useful because can help people find the items they are looking for.
#
# The most profitable categories (=tags):
# - kitchenware	24.259500
# - decor	20.750012
# - accessories	11.248377
#
# The mean price per item is 4,65. The minimum price is 0.001000, maximum is 38970. The majority of items cost 1.25-4.13.
#
# Items with normal prices (not too expensive) brought 974403, the most expensive items brought 3727.

# %%
labels=pie_chart['category'].to_list()
pie_chart['share'].plot.pie(figsize=(10, 10),autopct='%1.1f%%', 
                   textprops={'fontsize': 12}, labels=labels,legend=None, ylabel='')
plt.title('Shares of different categories') 
plt.show()

# %% [markdown]
# We found items frequently bought together and made association rules to improve the recommendation system.

# %% [markdown]
# **5. Hypotheses**
#
# We have checked two hypotheses.
#
# 1.  The average revenue from the clients who purchased once, doesn't differ from the average revenue from the clients who made multiple orders.
#
# We checked the equality of the variances and the normality of distribution (with the Shapiro test) to choose the statistical test correctly.
#
# After running a Mann-Whitney test we get the result.

# %%
#Null hypothesis - The average revenue from the clients who purchased once doesn't differs 
#from the average revenue from the clients who made multiple orders.

alpha = 0.05 

statistic, pvalue = st.mannwhitneyu(only_order_customers['total_price'], several_order_customers['total_price'], alternative = 'less')

print('p-value:', pvalue)

if pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value: 0.0
# We reject the null hypothesis

# %% [markdown]
# *So, we proved that there is a difference between the average revenue from the clients who purchased once doesn't differ from the average revenue from the clients who made multiple orders.*

# %% [markdown]
# 2. Is the average revenue from the orders with at least one item from kitchenware differ from the average revenue from the orders with at least one item from decor
#
# After checking the equality of the variances and normality of the data by using plots, we choose Mann-Whitney again to check the hypothesis.

# %%
#Null hypothesis - the average revenue from the orders with at least one kitchenware item is equal to
#the average revenue from the orders with at least one decor item

alpha = 0.05 

statistic, pvalue = st.mannwhitneyu(kitchenware['total_price'], decor['total_price'], alternative = 'less')

print('p-value:', pvalue)

if pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value: 1.0
# We can't reject the null hypothesis

# %% [markdown]
# *So we proved that the average revenue from the orders doesn't differ.*

# %% [markdown]
# **Recommendations**
#
# First of all, with our approach or another assortment hierarchy is needed. Some categories and tags will help in investigations.
#
# It would be better to make descriptions more accurate.
#
# We know the worst and best months in terms of orders and revenue. So it will help to enhance marketing decisions and targeting.
#
# We would suggest concentrating on decor, kitchenware, and accessories items. And we can assume that there is room for improving the recommendation system, so we created lists of items frequently bought together.

# %% [markdown]
# ### Sources
# - https://seaborn.pydata.org - for plotting graphs,
# - https://medium.com/@babagee500/hypothesis-testing-in-an-e-commerce-business-1025bdab1f1d - some insights abou the hypothesys testing in e-commerce
# - https://www.youtube.com/watch?v=4OORU17o1GY - assosiation rules and apriory
# - https://stackoverflow.com/questions/52393591/nltk-lemmatizer-extract-meaningful-words and few other topics about nltk
# - https://www.khanacademy.org/math/ap-statistics/xfb5d8e68:inference-categorical-proportions/idea-significance-tests/v/examples-of-null-and-alternative-hypotheses - for better understanding of hypothesis testing

# %% [markdown]
# ### Presentation
# https://docs.google.com/presentation/d/1cqcMChQCbklXxp_iBSnay-qnr5Fh3mnm326cOFIGd-0/edit?usp=sharing
